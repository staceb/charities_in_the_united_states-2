# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('charity_navigator_clean.csv', index_col = 0)

# %%
df.drop('charity_url', axis = 1, inplace = True)

# %%
df.head()
# Out:
#    accountability_score  administrative_expenses  \
# 0                  89.0                 164590.0
# 1                  86.0                1001560.0
# 2                  85.0                  93957.0
# 3                  86.0                 346867.0
# 4                  97.0                 135195.0
#
#                                  charity_name       city cn_advisory  \
# 0  9to5 National Association of Working Women  Milwaukee         NaN
# 1                             'Aha Pūnana Leo       Hilo         NaN
# 2                  AID FOR AIDS International   New York         NaN
# 3                        Futures in Education   Brooklyn         NaN
# 4                 Every Generation Ministries   Temecula         NaN
#
#    compensation_leader_compensation  compensation_leader_expense_percent  \
# 0                           53463.0                                 3.11
# 1                           73500.0                                 1.47
# ...

# %%
df.describe()
# Out:
#        accountability_score  administrative_expenses  \
# count           8190.000000             8.190000e+03
# mean              90.441758             1.235162e+06
# std                9.892188             5.773610e+06
# min               24.000000             7.230000e+02
# 25%               88.000000             1.824298e+05
# 50%               93.000000             3.543450e+05
# 75%               97.000000             8.078158e+05
# max              100.000000             2.569202e+08
#
#        compensation_leader_compensation  compensation_leader_expense_percent  \
# count                      7.290000e+03                          7290.000000
# mean                       1.659498e+05                             3.543462
# std                        1.298927e+05                             2.384256
# min                        1.000000e+00                             0.000000
# 25%                        9.155775e+04                             1.610000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8190 entries, 0 to 8189
# Data columns (total 20 columns):
# accountability_score                   8190 non-null float64
# administrative_expenses                8190 non-null float64
# charity_name                           8187 non-null object
# city                                   8189 non-null object
# cn_advisory                            6 non-null object
# compensation_leader_compensation       7290 non-null float64
# compensation_leader_expense_percent    7290 non-null float64
# compensation_leader_title              7827 non-null object
# excess_or_deficit_for_year             8190 non-null float64
# financial_score                        8190 non-null float64
# fundraising_expenses                   8190 non-null int64
# net_assets                             8190 non-null int64
# other_revenue                          8190 non-null float64
# overall_score                          8190 non-null float64
# ...

# %%
df.corr()
# Out:
#                                      accountability_score  \
# accountability_score                             1.000000
# administrative_expenses                          0.063908
# compensation_leader_compensation                 0.144920
# compensation_leader_expense_percent             -0.178192
# excess_or_deficit_for_year                       0.015231
# financial_score                                  0.165138
# fundraising_expenses                             0.067335
# net_assets                                       0.053949
# other_revenue                                    0.039374
# overall_score                                    0.691574
# payments_to_affiliates                           0.018528
# program_expenses                                 0.085477
# total_contributions                              0.089454
#
#                                      administrative_expenses  \
# accountability_score                                0.063908
# ...

# %%
df.corr()[(abs(df.corr() >= .25)) & (df.corr() != 1)]
# Out:
#                                      accountability_score  \
# accountability_score                                  NaN
# administrative_expenses                               NaN
# compensation_leader_compensation                      NaN
# compensation_leader_expense_percent                   NaN
# excess_or_deficit_for_year                            NaN
# financial_score                                       NaN
# fundraising_expenses                                  NaN
# net_assets                                            NaN
# other_revenue                                         NaN
# overall_score                                    0.691574
# payments_to_affiliates                                NaN
# program_expenses                                      NaN
# total_contributions                                   NaN
#
#                                      administrative_expenses  \
# accountability_score                                     NaN
# ...

# %%
plt.figure(figsize = (15, 8))

sns.heatmap(df.corr(), cmap = 'coolwarm', annot = True)
plt.title('df.corr()');

# %%
df_25_corr = df[df['compensation_leader_compensation'].isnull() == False]
df_25_corr.drop(['charity_name', 'city', 'cn_advisory', 'state',
                 'org_category', 'compensation_leader_title', 
                 'accountability_score', 'financial_score',
                 'overall_score', 'compensation_leader_expense_percent',
                 'payments_to_affiliates'],
                 axis = 1, inplace = True)
df_25_corr.head()
# Out:
# /Users/charlieyaris/.venvs/lpthw/lib/python3.6/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
#    administrative_expenses  compensation_leader_compensation  \
# 0                 164590.0                           53463.0
# 1                1001560.0                           73500.0
# 2                  93957.0                           85000.0
# 3                 346867.0                           61220.0
# 4                 135195.0                           74244.0
#
#    excess_or_deficit_for_year  fundraising_expenses  net_assets  \
# 0                    349718.0                111522     1350382
# 1                   1175965.0                 54613    14773920
# 2                   -461502.0                248833     -770370
# ...

# %%
sns.pairplot(df_25_corr, hue = 'org_type', palette = 'viridis');

# %%
df_expenses = df[df['compensation_leader_compensation'].isnull() == False]
df_expenses.drop(['charity_name', 'city', 'cn_advisory', 'state',
                  'org_category', 'compensation_leader_title', 
                  'accountability_score', 'financial_score',
                  'overall_score', 'excess_or_deficit_for_year',
                  'net_assets', 'other_revenue', 'total_contributions'],
                 axis = 1, inplace = True)
df_expenses.head()
# Out:
# /Users/charlieyaris/.venvs/lpthw/lib/python3.6/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
#    administrative_expenses  compensation_leader_compensation  \
# 0                 164590.0                           53463.0
# 1                1001560.0                           73500.0
# 2                  93957.0                           85000.0
# 3                 346867.0                           61220.0
# 4                 135195.0                           74244.0
#
#    compensation_leader_expense_percent  fundraising_expenses  \
# 0                                 3.11                111522
# 1                                 1.47                 54613
# 2                                 0.99                248833
# ...

# %%
sns.pairplot(df_expenses, hue = 'org_type', palette = 'viridis');

# %%
df_revenue = df[df['compensation_leader_compensation'].isnull() == False]
df_revenue.drop(['charity_name', 'city', 'cn_advisory', 'state', 
                 'org_category', 'compensation_leader_title', 
                 'accountability_score', 'financial_score',
                 'overall_score', 'administrative_expenses',
                 'compensation_leader_compensation',
                 'compensation_leader_expense_percent',
                 'fundraising_expenses', 'payments_to_affiliates',
                 'program_expenses'], axis = 1, inplace = True)
df_revenue.head()
# Out:
# /Users/charlieyaris/.venvs/lpthw/lib/python3.6/site-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
#    excess_or_deficit_for_year  net_assets  other_revenue  total_contributions  \
# 0                    349718.0     1350382        49634.0              1999023
# 1                   1175965.0    14773920       382540.0              3339358
# 2                   -461502.0     -770370            0.0              8039138
# 3                   1872733.0    11460087       -81726.0              9704138
# 4                   -103940.0      723772        32436.0              1234662
#
#                  org_type
# 0  Human and Civil Rights
# 1               Education
# 2           International
# 3               Education
# 4                Religion

# %%
sns.pairplot(df_revenue, hue = 'org_type', palette = 'viridis');

# %%
df_score = df[df['compensation_leader_compensation'].isnull() == False]
df_score.drop(['charity_name', 'city', 'cn_advisory', 'state',
               'org_category', 'compensation_leader_title', 
               'compensation_leader_expense_percent', 
               'administrative_expenses', 
               'compensation_leader_compensation',
               'compensation_leader_expense_percent', 
               'excess_or_deficit_for_year', 'fundraising_expenses',
               'net_assets', 'other_revenue', 'payments_to_affiliates',
               'program_expenses', 'total_contributions'], axis = 1, inplace = True)
df_score.head()
# Out:
# /Users/charlieyaris/.venvs/lpthw/lib/python3.6/site-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # Remove the CWD from sys.path while we load stuff.
#    accountability_score  financial_score  overall_score  \
# 0                  89.0            90.56          89.75
# 1                  86.0            85.92          85.95
# 2                  85.0            77.65          80.96
# 3                  86.0            97.50          89.94
# 4                  97.0            87.08          90.62
#
#                  org_type
# 0  Human and Civil Rights
# 1               Education
# 2           International
# 3               Education
# 4                Religion

# %%
sns.pairplot(df_score, hue = 'org_type', palette = 'viridis');
