# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
df = pd.read_csv('charity_navigator_clean.csv', index_col = 0)

# %%
df.drop('charity_url', axis = 1, inplace = True)

# %%
plt.figure(figsize = (15, 8))

sns.heatmap(df.corr(), cmap = 'coolwarm', annot = True)
plt.title('df.corr()');

# %%
financial_numbers = df.copy()
financial_numbers.drop(['compensation_leader_compensation', 'compensation_leader_expense_percent', 
                       'accountability_score', 'financial_score', 
                       'overall_score'],
                      axis = 1, inplace = True)

# %%
plt.figure(figsize = (15, 8))

sns.heatmap(pairplot_numbers.corr(), cmap = 'coolwarm', annot = True)
plt.title('financial_numbers.corr()');

# %%
sns.pairplot(financial_numbers);
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-40-242a3c553281> in <module>()
# ----> 1 sns.pairplot(financial_numbers);
#
# NameError: name 'financial_numbers' is not defined
