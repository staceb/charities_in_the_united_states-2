# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('charity_navigator_clean.csv', index_col = 0)

# %%
n = 0
for excess_or_deficit in df['excess_or_deficit_for_year']:
    if df.loc[n, 'excess_or_deficit_for_year'] > 0:
        df.loc[n, 'excess_or_deficit'] = 1
        n += 1
    elif df.loc[n, 'excess_or_deficit_for_year'] <= 0:
        df.loc[n, 'excess_or_deficit'] = 0
        n += 1
    else:
        n += 1

# %%
comp_leader_df = df[df['compensation_leader_compensation'].isnull() == False]
org_type_dummies = pd.get_dummies(comp_leader_df.org_type)
comp_leader_df = pd.concat([comp_leader_df, org_type_dummies], axis=1, join = 'outer')
comp_leader_df.drop(['charity_name', 'charity_url', 
                     'city', 'cn_advisory', 
                     'state', 'org_type',
                     'org_category', 'compensation_leader_title'], 
                    axis = 1, inplace = True)
comp_leader_df.head()
# Out:
#    accountability_score  administrative_expenses  \
# 0                  89.0                 164590.0
# 1                  86.0                1001560.0
# 2                  85.0                  93957.0
# 3                  86.0                 346867.0
# 4                  97.0                 135195.0
#
#    compensation_leader_compensation  compensation_leader_expense_percent  \
# 0                           53463.0                                 3.11
# 1                           73500.0                                 1.47
# 2                           85000.0                                 0.99
# 3                           61220.0                                 0.78
# 4                           74244.0                                 5.41
#
#    excess_or_deficit_for_year  financial_score  fundraising_expenses  \
# 0                    349718.0            90.56                111522
# 1                   1175965.0            85.92                 54613
# ...

# %%
comp_leader_df.describe()
# Out:
#        accountability_score  administrative_expenses  \
# count           7290.000000             7.290000e+03
# mean              91.338683             1.294414e+06
# std                8.873393             6.049582e+06
# min               24.000000             9.440000e+02
# 25%               89.000000             1.945552e+05
# 50%               93.000000             3.732055e+05
# 75%               97.000000             8.588372e+05
# max              100.000000             2.569202e+08
#
#        compensation_leader_compensation  compensation_leader_expense_percent  \
# count                      7.290000e+03                          7290.000000
# mean                       1.659498e+05                             3.543462
# std                        1.298927e+05                             2.384256
# min                        1.000000e+00                             0.000000
# 25%                        9.155775e+04                             1.610000
# ...

# %%
from sklearn.cluster import KMeans
from sklearn import metrics

# %%
kmeans = KMeans(n_clusters = 2)
kmeans.fit(comp_leader_df.drop('excess_or_deficit', axis = 1))
kmeans.cluster_centers_
# Out:
# array([[ 9.13342488e+01,  1.16559073e+06,  1.65427335e+05,
#          3.54721505e+00,  8.43823040e+05,  8.59619239e+01,
#          1.00947496e+06,  2.77356584e+07,  1.02064203e+06,
#          8.71737009e+01,  1.98015055e+04,  1.27869994e+07,
#          1.23216820e+07,  5.75391376e-02,  1.48173579e-01,
#          9.69513870e-02,  7.56660258e-02,  5.02609173e-02,
#          1.00109860e-01,  2.88244988e-01,  4.02361988e-02,
#          6.83878055e-02,  5.02609173e-02,  2.41691843e-02],
#        [ 9.53750000e+01,  1.18555475e+08,  6.41498375e+05,
#          1.27500000e-01,  5.75510856e+07,  9.00675000e+01,
#          5.67765586e+07,  4.08954906e+09,  1.56048525e+08,
#          9.15312500e+01, -3.63797881e-12,  6.18068418e+08,
#          5.04827543e+08,  6.93889390e-18,  2.50000000e-01,
#          1.25000000e-01,  0.00000000e+00,  1.25000000e-01,
#          5.00000000e-01,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  3.46944695e-18]])

# %%
print(metrics.classification_report(comp_leader_df['excess_or_deficit'], kmeans.labels_))
print(metrics.confusion_matrix(comp_leader_df['excess_or_deficit'], kmeans.labels_))
# Out:
#              precision    recall  f1-score   support
#
#         0.0       0.43      1.00      0.60      3126
#         1.0       0.50      0.00      0.00      4164
#
# avg / total       0.47      0.43      0.26      7290
#
# [[3122    4]
#  [4160    4]]
