# %%
import pandas as pd

# %%
df = pd.read_csv('charity_navigator_scraped.csv')

# %%
df.head()
# Out:
#    accountability_score administrative_expenses  \
# 0                  89.0                $164,590
# 1                  86.0              $1,001,560
# 2                  85.0                 $93,957
# 3                  86.0                $346,867
# 4                  97.0                $135,195
#
#                                  charity_name  \
# 0  9to5 National Association of Working Women
# 1                             'Aha Pūnana Leo
# 2                  AID FOR AIDS International
# 3                        Futures in Education
# 4                 Every Generation Ministries
#
#                                          charity_url                  city  \
# 0  https://www.charitynavigator.org/index.cfm?bay...           ' Milwaukee
# 1  https://www.charitynavigator.org/index.cfm?bay...       '\r\n\t\t\tHilo
# 2  https://www.charitynavigator.org/index.cfm?bay...            ' New York
# 3  https://www.charitynavigator.org/index.cfm?bay...   '\r\n\t\t\tBrooklyn
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8190 entries, 0 to 8189
# Data columns (total 20 columns):
# accountability_score                   8190 non-null float64
# administrative_expenses                8190 non-null object
# charity_name                           8187 non-null object
# charity_url                            8190 non-null object
# city                                   8189 non-null object
# cn_advisory                            6 non-null object
# compensation_leader_compensation       7763 non-null object
# compensation_leader_expense_percent    8190 non-null object
# compensation_leader_title              7827 non-null object
# excess_or_deficit_for_year             8190 non-null object
# financial_score                        8190 non-null float64
# fundraising_expenses                   8190 non-null object
# net_assets                             8190 non-null object
# organization_type                      8190 non-null object
# ...
